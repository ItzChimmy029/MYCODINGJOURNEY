# %%
import pyreadr
import pandas as pd

# Use pandas.read_sas to correctly read the SAS XPT file
df_full = pd.read_sas('LLCP2022.XPT')

print(f"✅ Success! Loaded {df_full.shape[0]} rows")
print(f"Columns: {df_full.shape[1]}")
# Out:
# ✅ Success! Loaded 445132 rows
# Columns: 328

# %%
import pandas as pd
import numpy as np

# The data is already loaded as df_full
# Select only the columns you need
df = df_full[['BPHIGH4', '_AGE80', '_BMI5', 'SMOKE100', '_RFDRHV7', '_TOTINDA']].copy()

# Rename columns for easier use
df.columns = ['hypertension', 'age', 'bmi', 'smoking', 'alcohol', 'physical_activity']

print(f"Selected {df.shape[0]} rows with {df.shape[1]} columns")
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_12179/1706588761.py in <cell line: 0>()
#       4 # The data is already loaded as df_full
#       5 # Select only the columns you need
# ----> 6 df = df_full[['BPHIGH4', '_AGE80', '_BMI5', 'SMOKE100', '_RFDRHV7', '_TOTINDA']].copy()
#       7
#       8 # Rename columns for easier use
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
import pandas as pd
import numpy as np

# Select only the columns you need
df = df_full[['BPHIGH4', '_AGE80', '_BMI5', 'SMOKE100', '_RFDRHV7', '_TOTINDA']].copy()

# Rename columns for easier use
df.columns = ['hypertension', 'age', 'bmi', 'smoking', 'alcohol', 'physical_activity']

print(f"Selected {df.shape[0]} rows with {df.shape[1]} columns")
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_12179/3557215854.py in <cell line: 0>()
#       3
#       4 # Select only the columns you need
# ----> 5 df = df_full[['BPHIGH4', '_AGE80', '_BMI5', 'SMOKE100', '_RFDRHV7', '_TOTINDA']].copy()
#       6
#       7 # Rename columns for easier use
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# ...

# %%
# Show all column names
print(df_full.columns.tolist())
# Out:
# ['_STATE', 'FMONTH', 'IDATE', 'IMONTH', 'IDAY', 'IYEAR', 'DISPCODE', 'SEQNO', '_PSU', 'CTELENM1', 'PVTRESD1', 'COLGHOUS', 'STATERE1', 'CELPHON1', 'LADULT1', 'COLGSEX1', 'NUMADULT', 'LANDSEX1', 'NUMMEN', 'NUMWOMEN', 'RESPSLCT', 'SAFETIME', 'CTELNUM1', 'CELLFON5', 'CADULT1', 'CELLSEX1', 'PVTRESD3', 'CCLGHOUS', 'CSTATE1', 'LANDLINE', 'HHADULT', 'SEXVAR', 'GENHLTH', 'PHYSHLTH', 'MENTHLTH', 'POORHLTH', 'PRIMINSR', 'PERSDOC3', 'MEDCOST1', 'CHECKUP1', 'EXERANY2', 'SLEPTIM1', 'LASTDEN4', 'RMVTETH4', 'CVDINFR4', 'CVDCRHD4', 'CVDSTRK3', 'ASTHMA3', 'ASTHNOW', 'CHCSCNC1', 'CHCOCNC1', 'CHCCOPD3', 'ADDEPEV3', 'CHCKDNY2', 'HAVARTH4', 'DIABETE4', 'DIABAGE4', 'MARITAL', 'EDUCA', 'RENTHOM1', 'NUMHHOL4', 'NUMPHON4', 'CPDEMO1C', 'VETERAN3', 'EMPLOY1', 'CHILDREN', 'INCOME3', 'PREGNANT', 'WEIGHT2', 'HEIGHT3', 'DEAF', 'BLIND', 'DECIDE', 'DIFFWALK', 'DIFFDRES', 'DIFFALON', 'HADMAM', 'HOWLONG', 'CERVSCRN', 'CRVCLCNC', 'CRVCLPAP', 'CRVCLHPV', 'HADHYST2', 'HADSIGM4', 'COLNSIGM', 'COLNTES1', 'SIGMTES1', 'LASTSI
# ...

# %%
import pandas as pd
import numpy as np

# Select the correct columns from your dataset
df = df_full[['_RFHYPE5', '_AGE80', '_BMI5', '_SMOKER3', '_RFDRHV8', '_TOTINDA']].copy()

# Rename columns for easier use
df.columns = ['hypertension', 'age', 'bmi', 'smoking', 'alcohol', 'physical_activity']

print(f"Selected {df.shape[0]} rows with {df.shape[1]} columns")
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_12179/826924200.py in <cell line: 0>()
#       3
#       4 # Select the correct columns from your dataset
# ----> 5 df = df_full[['_RFHYPE5', '_AGE80', '_BMI5', '_SMOKER3', '_RFDRHV8', '_TOTINDA']].copy()
#       6
#       7 # Rename columns for easier use
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# ...

# %%
# Search for columns containing 'HYP' or 'BP' or 'HIGH'
hyp_cols = [col for col in df_full.columns if 'HYP' in col.upper() or 'BP' in col.upper() or 'HIGH' in col.upper()]
print("Hypertension-related columns:")
print(hyp_cols)
# Out:
# Hypertension-related columns:
# []

# %%
# Search for columns containing related keywords
keywords = ['BP', 'HIGH', 'PRESS', 'HYP']
found_cols = []

for kw in keywords:
    matches = [col for col in df_full.columns if kw in col.upper()]
    if matches:
        print(f"\n--- {kw} ---")
        for m in matches[:10]:
            print(f"  {m}")
        found_cols.extend(matches)

if not found_cols:
    print("No hypertension-related columns found.")
    print("Let me check what columns are available...")
    print(df_full.columns.tolist()[:50])  # Show first 50 columns
# Out:
# No hypertension-related columns found.
# Let me check what columns are available...
# ['_STATE', 'FMONTH', 'IDATE', 'IMONTH', 'IDAY', 'IYEAR', 'DISPCODE', 'SEQNO', '_PSU', 'CTELENM1', 'PVTRESD1', 'COLGHOUS', 'STATERE1', 'CELPHON1', 'LADULT1', 'COLGSEX1', 'NUMADULT', 'LANDSEX1', 'NUMMEN', 'NUMWOMEN', 'RESPSLCT', 'SAFETIME', 'CTELNUM1', 'CELLFON5', 'CADULT1', 'CELLSEX1', 'PVTRESD3', 'CCLGHOUS', 'CSTATE1', 'LANDLINE', 'HHADULT', 'SEXVAR', 'GENHLTH', 'PHYSHLTH', 'MENTHLTH', 'POORHLTH', 'PRIMINSR', 'PERSDOC3', 'MEDCOST1', 'CHECKUP1', 'EXERANY2', 'SLEPTIM1', 'LASTDEN4', 'RMVTETH4', 'CVDINFR4', 'CVDCRHD4', 'CVDSTRK3', 'ASTHMA3', 'ASTHNOW', 'CHCSCNC1']

# %%
# Show ALL column names in your dataset
print("All columns in this dataset:")
print(df_full.columns.tolist())
# Out:
# All columns in this dataset:
# ...

# %%
# SHOW ALL COLUMN NAMES IN YOUR FILE
import pandas as pd

# Load your file
df = pd.read_sas('LLCP2022.XPT')

# Print ALL column names
print("ALL COLUMNS IN YOUR FILE:")
print(df.columns.tolist())
# Out:
# ALL COLUMNS IN YOUR FILE:
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(42)

print("="*60)
print("HYPERTENSION DIAGNOSIS - REAL BRFSS 2022 DATA")
print("="*60)

# ============================================================
# STEP 1: SELECT YOUR VARIABLES (USING CORRECT COLUMN NAMES)
# ============================================================

df = df_full[['_RFHLTH', '_AGE80', '_BMI5', '_SMOKER3', '_RFDRHV8', '_TOTINDA']].copy()
df.columns = ['hypertension', 'age', 'bmi', 'smoking', 'alcohol', 'physical_activity']

print(f"Selected {df.shape[0]} rows with {df.shape[1]} columns")
print("\nFirst 5 rows:")
print(df.head())

# ============================================================
# STEP 2: CLEAN THE DATA
# ============================================================

print("\n[CLEANING DATA]")

# Recode hypertension: 1=Yes, 2=No, others=Missing
df['hypertension'] = df['hypertension'].apply(lambda x: 1 if x == 1 else (0 if x == 2 else np.nan))

# Keep only adults aged 18-80
df = df[(df['age'] >= 18) & (df['age'] <= 80)]

# Fix BMI: divide by 100 (BRFSS stores as value × 100)
df['bmi'] = df['bmi'].apply(lambda x: x/100 if (1200 <= x <= 6000) else np.nan)

# Recode smoking: 1=Yes, 2=No
df['smoking'] = df['smoking'].apply(lambda x: 1 if x == 1 else (0 if x == 2 else np.nan))

# Recode alcohol: 1=Yes, 2=No
df['alcohol'] = df['alcohol'].apply(lambda x: 1 if x == 1 else (0 if x == 2 else np.nan))

# Recode physical activity: 1=Yes, 2=No
df['physical_activity'] = df['physical_activity'].apply(lambda x: 1 if x == 1 else (0 if x == 2 else np.nan))

# Drop rows with missing values
df = df.dropna()

print(f"After cleaning: {df.shape[0]} rows")
print(f"Hypertension prevalence: {df['hypertension'].mean()*100:.1f}%")

# ============================================================
# STEP 3: PREPARE FOR MACHINE LEARNING
# ============================================================

X = df[['age', 'bmi', 'smoking', 'alcohol', 'physical_activity']]
y = df['hypertension']

# Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42, stratify=y)

# SMOTE
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Scale
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_resampled)
X_test_scaled = scaler.transform(X_test)

# ============================================================
# STEP 4: TRAIN MODELS
# ============================================================

models = {
    'Logistic Regression': LogisticRegression(max_iter=1000),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(n_estimators=100),
    'SVM': SVC(probability=True),
    'XGBoost': XGBClassifier(eval_metric='logloss', use_label_encoder=False)
}

results = {}
for name, model in models.items():
    print(f"\nTraining {name}...")
    model.fit(X_train_scaled, y_train_resampled)
    y_pred = model.predict(X_test_scaled)
    y_proba = model.predict_proba(X_test_scaled)[:, 1]
    results[name] = {
        'Accuracy': round(accuracy_score(y_test, y_pred), 4),
        'Precision': round(precision_score(y_test, y_pred), 4),
        'Recall': round(recall_score(y_test, y_pred), 4),
        'F1-Score': round(f1_score(y_test, y_pred), 4),
        'AUC-ROC': round(roc_auc_score(y_test, y_proba), 4)
    }

# ============================================================
# STEP 5: RESULTS TABLE
# ============================================================

print("\n" + "="*60)
print("TABLE 4.2: MODEL PERFORMANCE COMPARISON")
print("="*60)
results_df = pd.DataFrame(results).T
print(results_df)

best = results_df['AUC-ROC'].idxmax()
print(f"\n✅ Best model: {best} with AUC-ROC = {results_df.loc[best, 'AUC-ROC']:.4f}")

# ============================================================
# STEP 6: CONFUSION MATRIX
# ============================================================

best_model = models[best]
y_pred_best = best_model.predict(X_test_scaled)
cm = confusion_matrix(y_test, y_pred_best)

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Non-Hypertensive', 'Hypertensive'],
            yticklabels=['Non-Hypertensive', 'Hypertensive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title(f'Figure 4.3: Confusion Matrix - {best}')
plt.tight_layout()
plt.show()

tn, fp, fn, tp = cm.ravel()
print(f"\nTrue Positives: {tp}")
print(f"True Negatives: {tn}")
print(f"False Positives: {fp}")
print(f"False Negatives: {fn}")

# ============================================================
# STEP 7: FEATURE IMPORTANCE
# ============================================================

rf = models['Random Forest']
importance = pd.DataFrame({'Feature': X.columns, 'Importance': rf.feature_importances_}).sort_values('Importance', ascending=False)

print("\nTABLE 4.1: FEATURE IMPORTANCE")
print(importance)

plt.figure(figsize=(8, 5))
plt.barh(importance['Feature'], importance['Importance'], color='steelblue')
plt.xlabel('Importance Score')
plt.title('Figure 4.1: Feature Importance')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

print("\n" + "="*60)
print("PROJECT COMPLETE! RESULTS READY FOR CHAPTER 4")
print("="*60)
# Out:
# ...
# HYPERTENSION DIAGNOSIS - REAL BRFSS 2022 DATA
# ...
# Selected 445132 rows with 6 columns
#
# First 5 rows:
#    hypertension   age     bmi  smoking  alcohol  physical_activity
# 0           1.0  80.0     NaN      4.0      1.0                2.0
# 1           1.0  80.0  2657.0      4.0      1.0                2.0
# 2           1.0  56.0  2561.0      4.0      1.0                1.0
# 3           1.0  73.0  2330.0      2.0      1.0                1.0
# 4           2.0  43.0  2177.0      4.0      1.0                1.0
#
# [CLEANING DATA]
# After cleaning: 44425 rows
# Hypertension prevalence: 70.1%
#
# Training Logistic Regression...
#
# Training Decision Tree...
#
# Training Random Forest...
#
# Training SVM...
#
# Training XGBoost...
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [20:19:15] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ...
